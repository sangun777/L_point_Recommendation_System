# %% [markdown]
# # 대분류명으로 부터 중분류명 생성
#
#     * 검색어(sech_kwd)와 롯데홈쇼핑사이트 크롤링을 통해 얻은 대분류명(sech_clac_nm1)를 활용하여 중분류명(sech_clac_nm2) 생성
#     * 실제 거래정보내 해당 대분류안에서 거래가 이루어진 중분류명 비율을 적용하여 랜덤하게 생성

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas()

import random
random.seed(1)
# Out:
# /home/aiffel0042/anaconda3/envs/aiffel/lib/python3.8/site-packages/tqdm/std.py:725: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %% [markdown]
#  * raw 데이터 불러오기

# %%
# 1. 온라인 행동 데이터
raw_data1_Online_Act = pd.read_csv('./data/data1_Online_Act.csv')

# 2. 거래 정보 데이터
raw_data2_Trade_Inform = pd.read_csv('./data/data2_Trade_Inform.csv')

# 3. 사용자 demo 정보(나이, 성별)
raw_data3_Demog = pd.read_csv('./data/data3_Demog.csv')

# 4. 상품 대중소 분류 정보
raw_data4_Item_Class = pd.read_csv('./data/data4_Item_Class.csv')
# Out:
# /home/aiffel0042/anaconda3/envs/aiffel/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### 2. 거래정보와 4. 분류명 정보를 결합하여 각 대분류 내에서 중분류의 거래 비율이 얼마나 되는지 확인

# %%
raw_data2_Trade_Inform
# Out:
#         clnt_id  trans_id  trans_seq biz_unit     pd_c     de_dt  de_tm  \
# 0         21922    104999          1      A03  unknown  20190920  12:41
# 1         21279    104907          4      A03  unknown  20190920  10:27
# 2         39423    105124         11      A03  unknown  20190920  17:26
# 3         18362    104010          1      A03  unknown  20190920  09:57
# 4         39423    105124         13      A03     0565  20190920  17:26
# ...         ...       ...        ...      ...      ...       ...    ...
# 599956    35311      2839          3      B03     0339  20190927  14:09
# 599957    35311      2839          4      B03     0339  20190927  14:09
# 599958    35311      2839          5      B03     0339  20190927  14:09
# 599959    35311      2839          2      B03     0339  20190927  14:09
# 599960    35311      2839          6      B03     0324  20190927  14:09
#
#         buy_am  buy_ct
# 0         5990       1
# 1        10900       1
# 2        12900       1
# 3         9900       1
# 4         2990       1
# ...        ...     ...
# 599956    3500       1
# 599957    3600       2
# 599958    3500       1
# 599959    4500       1
# 599960    6800       1
#
# [599961 rows x 9 columns]

# %%
raw_data4_Item_Class.head(3)
# Out:
#    pd_c             clac_nm1  \
# 0     1  Automotive Products
# 1     2  Automotive Products
# 2     3  Automotive Products
#
#                                            clac_nm2  \
# 0  Automotive Replacement Repair / Maintanance Kits
# 1  Automotive Replacement Repair / Maintanance Kits
# 2  Automotive Replacement Repair / Maintanance Kits
#
#                      clac_nm3
# 0  Automobile Oil / Additives
# 1                  Car Lights
# 2                   Car Paint

# %% [markdown]
#  * 결측치 확인

# %%
raw_data4_Item_Class.isna().sum()
# Out:
# pd_c        0
# clac_nm1    0
# clac_nm2    0
# clac_nm3    2
# dtype: int64

# %% [markdown]
#  * 2.거래정보 데이터에 4.상품분류명 데이터 병합

# %% [markdown]
#     * merge의 key역할을 수행하기 위해 raw_data4_Item_Class['pd_c'] data를 raw_data2와 동일한 str 형으로 변경
#
#      ### 4. 데이터 병합을 위하여 상품 이름정보의 pd_c 데이터 타입 변경 (int -> str)
#      * raw_data2_Trade_Inform에 있는 pd_c열의 경우, NaN과 unknown 값을 포함하기 때문에,
#        자료형을 int나 float로 변경할 수 없음(변경 시, 에러 발생)
#      * 따라서 4. 상품 이름 정보의 pd_c를 str 형으로 자료형 변경
#      * 그냥 object 형으로만 변경 시, 값이 같아도
#          merge_raw123 에서는 pd_c = '0062'(str형)으로 인식하고,
#          4. 상품이름 정보에서는 pd_c = 62(int형으로 인식해서 병합 시, 데이터 matching이 안됨

# %%
# 4. 상품 이름 데이터의 'pd_c' 열의 값을 4자리 숫자로 변환합니다.
# 예시) '1' => '0001', '62' => '0062', '773' => '0773' 

raw_data4_Item_Class['pd_c'] = raw_data4_Item_Class['pd_c'].astype('str')

cnt_add_zero = 0

for i in range(999):
    cnt_add_zero = 4 - len(raw_data4_Item_Class['pd_c'][i])
    add_zero = "0" * cnt_add_zero
    raw_data4_Item_Class['pd_c'][i] = add_zero + raw_data4_Item_Class['pd_c'][i]

# %%
merge_raw24 = pd.merge(raw_data2_Trade_Inform, raw_data4_Item_Class, on='pd_c', how='left')

# %%
merge_raw24
# Out:
#         clnt_id  trans_id  trans_seq biz_unit     pd_c     de_dt  de_tm  \
# 0         21922    104999          1      A03  unknown  20190920  12:41
# 1         21279    104907          4      A03  unknown  20190920  10:27
# 2         39423    105124         11      A03  unknown  20190920  17:26
# 3         18362    104010          1      A03  unknown  20190920  09:57
# 4         39423    105124         13      A03     0565  20190920  17:26
# ...         ...       ...        ...      ...      ...       ...    ...
# 599956    35311      2839          3      B03     0339  20190927  14:09
# 599957    35311      2839          4      B03     0339  20190927  14:09
# 599958    35311      2839          5      B03     0339  20190927  14:09
# 599959    35311      2839          2      B03     0339  20190927  14:09
# 599960    35311      2839          6      B03     0324  20190927  14:09
#
#         buy_am  buy_ct                 clac_nm1         clac_nm2  \
# 0         5990       1                      NaN              NaN
# 1        10900       1                      NaN              NaN
# 2        12900       1                      NaN              NaN
# 3         9900       1                      NaN              NaN
# 4         2990       1                   Fruits  Imported Fruits
# ...        ...     ...                      ...              ...
# 599956    3500       1  Cosmetics / Beauty Care        Skin Care
# 599957    3600       2  Cosmetics / Beauty Care        Skin Care
# 599958    3500       1  Cosmetics / Beauty Care        Skin Care
# 599959    4500       1  Cosmetics / Beauty Care        Skin Care
# 599960    6800       1  Cosmetics / Beauty Care           Makeup
#
#                       clac_nm3
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                      Bananas
# ...                        ...
# 599956            Facial Masks
# 599957            Facial Masks
# 599958            Facial Masks
# 599959            Facial Masks
# 599960  Nail Stickers / Stones
#
# [599961 rows x 12 columns]

# %% [markdown]
#  * 실제 거래에서 각 대분류(clac_nm1) 별 거래 갯수 확인

# %%
merge_raw24['clac_nm1'].value_counts()
# Out:
# Vegetables                                   69308
# Snack Foods                                  58880
# Dairy Products                               46474
# Meats                                        44157
# Chilled Foods                                43926
# Substitute Foods                             42477
# Beverages                                    34756
# Fruits                                       33540
# Frozen Foods                                 30104
# Spices / Seasonings                          20425
# Liquors / Alcoholic Beverages                16279
# Kitchenware                                  12588
# Cleaning / Laundry / Bathroom Accessories    12157
# Detergents / Hygiene Goods                   11942
# Sea Foods                                     9897
# Personal Care                                 8858
# Dried Sea Foods                               8652
# Canned / Jarred Foods                         7715
# Cosmetics / Beauty Care                       7252
# Cooked Foods                                  7053
# Tenants / Restaurants                         5619
# Women's Clothing                              5534
# Underwear / Socks and Hosiery / Homewear      4216
# Coffee / Tea                                  3982
# Grains                                        3561
# Fashion Accessories                           3553
# Toy                                           2645
# Stationary / Office Supplies                  2484
# Health Foods                                  2259
# Baby Foods                                    2027
# Birth Supplies / Baby Products                2016
# Tableware / Cooking Utensils                  1909
# Gardening / Pets                              1855
# Sport Fashion                                 1835
# Kids' Clothing                                1668
# Tools / Safety Supplies                       1203
# Bedding / Handicraft                          1117
# Men's Clothing                                 990
# Outdoor / Leisure Activities                   820
# Automotive Products                            758
# Health Care                                    656
# Others (Non-Products)                          642
# Home / Kitchen Appliances                      586
# Home Decor / Lighting                          524
# Seasonal Sports                                497
# Tobacco                                        475
# Ball Game / Field Sports                       432
# Furniture                                      380
# Books / Records / Instruments                  318
# Heating / Cooling Electronics                  202
# Health / Fitness Training                      182
# Gift Certificates / Cards                      172
# Cell Phones / Accessories                      165
# Other Products                                 136
# Computers                                      119
# Travel / Leisure Services                      109
# Video / Audio System Electronics                96
# Refrigerators and Washing Machines              78
# Living / Rental Services                        36
# Finance / Insurance Service                     13
# Name: clac_nm1, dtype: int64

# %% [markdown]
#  * 실제 거래에서 각 대분류(clac_nm1) 별 중분류(clac_nm2) 갯수 확인

# %%
merge_raw24['clac_nm2'][merge_raw24['clac_nm1'] == 'Vegetables'].value_counts()
# Out:
# Tofu / Bean Sprouts       18153
# Leaf Vegetables           15594
# Fruit Vegetables          14155
# Mushrooms                  7244
# Root Vegetables            6903
# Western Vegetables         6166
# Korean Greens / Namuls      792
# Chinese Herb Medicines      284
# Vegetable Gift Sets          17
# Name: clac_nm2, dtype: int64

# %% [markdown]
#  * 대분류가 'Vegetables' 일 때, 각 중분류가 나올 확률

# %%
merge_raw24['clac_nm2'][merge_raw24['clac_nm1'] == 'Vegetables'].value_counts() / merge_raw24['clac_nm2'][merge_raw24['clac_nm1'] == 'Vegetables'].value_counts().sum()
# Out:
# Tofu / Bean Sprouts       0.261918
# Leaf Vegetables           0.224996
# Fruit Vegetables          0.204233
# Mushrooms                 0.104519
# Root Vegetables           0.099599
# Western Vegetables        0.088965
# Korean Greens / Namuls    0.011427
# Chinese Herb Medicines    0.004098
# Vegetable Gift Sets       0.000245
# Name: clac_nm2, dtype: float64

# %%
list(merge_raw24['clac_nm2'][merge_raw24['clac_nm1'] == 'Vegetables'].value_counts() / merge_raw24['clac_nm2'][merge_raw24['clac_nm1'] == 'Vegetables'].value_counts().sum())
# Out:
# [0.26191781612512266,
#  0.22499567149535407,
#  0.2042332775437179,
#  0.10451895885034916,
#  0.09959889190281064,
#  0.08896519882264674,
#  0.011427252265250765,
#  0.0040976510648121425,
#  0.0002452819299359381]

# %% [markdown]
#  * 대분류'Vegetables'내 중분류 리스트

# %%
ind = list(merge_raw24['clac_nm2'][merge_raw24['clac_nm1'] == 'Vegetables'].value_counts().index)
ind
# Out:
# ['Tofu / Bean Sprouts',
#  'Leaf Vegetables',
#  'Fruit Vegetables',
#  'Mushrooms',
#  'Root Vegetables',
#  'Western Vegetables',
#  'Korean Greens / Namuls',
#  'Chinese Herb Medicines',
#  'Vegetable Gift Sets']

# %% [markdown]
#  * 대분류 리스트

# %%
list_clac_nm1 = list(merge_raw24['clac_nm1'].value_counts().index)
list_clac_nm1
# Out:
# ['Vegetables',
#  'Snack Foods',
#  'Dairy Products',
#  'Meats',
#  'Chilled Foods',
#  'Substitute Foods',
#  'Beverages',
#  'Fruits',
#  'Frozen Foods',
#  'Spices / Seasonings',
#  'Liquors / Alcoholic Beverages',
#  'Kitchenware',
#  'Cleaning / Laundry / Bathroom Accessories',
#  'Detergents / Hygiene Goods',
#  'Sea Foods',
#  'Personal Care',
#  'Dried Sea Foods',
#  'Canned / Jarred Foods',
#  'Cosmetics / Beauty Care',
#  'Cooked Foods',
#  'Tenants / Restaurants',
#  "Women's Clothing",
#  'Underwear / Socks and Hosiery / Homewear',
#  'Coffee / Tea',
#  'Grains',
#  'Fashion Accessories',
#  'Toy',
#  'Stationary / Office Supplies',
#  'Health Foods',
#  'Baby Foods',
#  'Birth Supplies / Baby Products',
#  'Tableware / Cooking Utensils',
#  'Gardening / Pets',
#  'Sport Fashion',
#  "Kids' Clothing",
#  'Tools / Safety Supplies',
#  'Bedding / Handicraft',
#  "Men's Clothing",
#  'Outdoor / Leisure Activities',
#  'Automotive Products',
#  'Health Care',
#  'Others (Non-Products)',
#  'Home / Kitchen Appliances',
#  'Home Decor / Lighting',
#  'Seasonal Sports',
#  'Tobacco',
#  'Ball Game / Field Sports',
#  'Furniture',
#  'Books / Records / Instruments',
#  'Heating / Cooling Electronics',
#  'Health / Fitness Training',
#  'Gift Certificates / Cards',
#  'Cell Phones / Accessories',
#  'Other Products',
#  'Computers',
#  'Travel / Leisure Services',
#  'Video / Audio System Electronics',
#  'Refrigerators and Washing Machines',
#  'Living / Rental Services',
#  'Finance / Insurance Service']

# %%
'Vegetables' in list_clac_nm1
# Out:
# True

# %% [markdown]
#  * 대분류명을 입력하면 해당 대분류 내에 중분류 비율에 맞추어 중분류명 반환하는 함수 정의

# %%
def clac_nm1_to_nm2(calc_name1):
    
    # 대분류명이 정상일 경우,
    if calc_name1 in list_clac_nm1:
        
        # 입력받은 대분류에 포함된 중분류 리스트
        c_nm2_list = list(merge_raw24['clac_nm2'][merge_raw24['clac_nm1'] == calc_name1].value_counts().index)
        
        # 대분류에 따른 중분류 확률
        probs = list(merge_raw24['clac_nm2'][merge_raw24['clac_nm1'] == calc_name1].value_counts() / merge_raw24['clac_nm2'][merge_raw24['clac_nm1'] == calc_name1].value_counts().sum())
        
        c_nm2_choiced = random.choices(c_nm2_list, weights = probs)
        
        return c_nm2_choiced[0]
    
    # 대분류명이 결측치 또는 비정상일 경우,
    else:
        return np.nan

# %% [markdown]
#  * 함수 동작 test

# %%
clac_nm1_to_nm2('unown')
# Out:
# nan

# %%
clac_nm1_to_nm2(merge_table['sech_clac_nm1'][0])
# Out:
# nan

# %%
clac_nm1_to_nm2('Vegetables')
# Out:
# 'Leaf Vegetables'

# %% [markdown]
#  * Merge Data 불러오기

# %%
merge_table = pd.read_csv("merge_sech_clac_nm1.csv")
merge_table.drop("Unnamed: 0", axis=1, inplace=True)
# Out:
# /home/aiffel0042/anaconda3/envs/aiffel/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (17,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
merge_table
# Out:
#          clnt_id  sess_id  hit_seq  action_type biz_unit   sess_dt hit_tm  \
# 0          72429        1        2            2      A03  20190919  22:09
# 1          72429        1        1            1      A03  20190919  22:09
# 2          72428        5        1            0      A01  20190918  06:37
# 3          72428        4        1            0      A01  20190914  23:42
# 4          72428        3        3            0      A01  20190914  21:50
# ...          ...      ...      ...          ...      ...       ...    ...
# 3196357        1        2        2            0      A01  20190922  14:10
# 3196358        1        2        1            0      A01  20190922  14:09
# 3196359        1        1        3            0      A01  20190911  16:15
# 3196360        1        1        2            0      A01  20190911  16:15
# 3196361        1        1        1            0      A01  20190911  16:14
#
#          hit_pss_tm  trans_id    sech_kwd  ...  clnt_gender  clnt_age  \
# 0            842130       NaN         NaN  ...      unknown   unknown
# 1            839064       NaN         NaN  ...      unknown   unknown
# 2             12568       NaN   라인에디션블라우스  ...      unknown   unknown
# 3            243555       NaN        펜디가방  ...      unknown   unknown
# 4            839771       NaN      페레가모가방  ...      unknown   unknown
# ...             ...       ...         ...  ...          ...       ...
# 3196357       56113       NaN      초등가을점퍼  ...      unknown   unknown
# 3196358       41584       NaN      초등가을잠바  ...      unknown   unknown
# 3196359       36140       NaN       과일바구니  ...      unknown   unknown
# 3196360       22432       NaN  과일선물세트 백화점  ...      unknown   unknown
# 3196361       11880       NaN      과일선물세트  ...      unknown   unknown
#
#         clac_nm1 clac_nm2 clac_nm3  pd_c_2 sech_kwd_over_3  sech_kwd_cat_0  \
# 0            NaN      NaN      NaN     NaN             NaN             NaN
# 1            NaN      NaN      NaN     NaN             NaN             NaN
# 2            NaN      NaN      NaN     NaN             NaN             NaN
# 3            NaN      NaN      NaN     NaN            펜디가방          명품/쥬얼리
# 4            NaN      NaN      NaN     NaN          페레가모가방          명품/쥬얼리
# ...          ...      ...      ...     ...             ...             ...
# 3196357      NaN      NaN      NaN     NaN             NaN             NaN
# 3196358      NaN      NaN      NaN     NaN             NaN             NaN
# 3196359      NaN      NaN      NaN     NaN           과일바구니        여행/렌탈/금융
# 3196360      NaN      NaN      NaN     NaN             NaN             NaN
# 3196361      NaN      NaN      NaN     NaN          과일선물세트              식품
#
#         sech_kwd_cat_1             sech_clac_nm1
# 0                  NaN                       NaN
# 1                  NaN                       NaN
# 2                  NaN                       NaN
# 3            수입명품/해외배송       Fashion Accessories
# 4            수입명품/해외배송       Fashion Accessories
# ...                ...                       ...
# 3196357            NaN                       NaN
# 3196358            NaN                       NaN
# 3196359       렌탈/배달/케어  Living / Rental Services
# 3196360            NaN                       NaN
# 3196361           신선식품             Chilled Foods
#
# [3196362 rows x 31 columns]

# %% [markdown]
#  * 함수 수행시간이 너무 길어서 데이터를 쪼개서 수행 (40만개씩 8분할)

# %%
merge_table_1 = merge_table[0:400000]
merge_table_2 = merge_table[400000:800000]
merge_table_3 = merge_table[800000:1200000]
merge_table_4 = merge_table[1200000:1600000]
merge_table_5 = merge_table[1600000:2000000]
merge_table_6 = merge_table[2000000:2400000]
merge_table_7 = merge_table[2400000:2800000]
merge_table_8 = merge_table[2800000:3196362]

# %% [markdown]
#  * 0 ~ 40만개

# %%
merge_table_1['sech_clac_nm2'] = merge_table_1['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)
# Out:
# 100%|██████████| 400000/400000 [3:04:43<00:00, 36.09it/s]
# <ipython-input-143-13ee25f0da8d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_table_1['sech_clac_nm2'] = merge_table_1['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)

# %%
merge_table_1.to_csv("merge_1_create_sech_clac_nm2.csv")

# %% [markdown]
#  * 40 ~ 80만개

# %%
merge_table_2['sech_clac_nm2'] = merge_table_2['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)
# Out:
# 100%|██████████| 400000/400000 [3:04:13<00:00, 36.19it/s]
# <ipython-input-145-d89fa8feeace>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_table_2['sech_clac_nm2'] = merge_table_2['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)

# %%
merge_table_2.to_csv("merge_2_create_sech_clac_nm2.csv")

# %% [markdown]
#  * 80 ~ 120만개

# %%
merge_table_3['sech_clac_nm2'] = merge_table_3['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)
# Out:
# 100%|██████████| 400000/400000 [2:58:18<00:00, 37.39it/s]
# <ipython-input-147-ce8c9be0bedb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_table_3['sech_clac_nm2'] = merge_table_3['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)

# %%
merge_table_3.to_csv("merge_3_create_sech_clac_nm2.csv")

# %% [markdown]
#  * 120 ~ 160만개

# %%
# merge_table_4['sech_clac_nm2'] = merge_table_4['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)

# %%
# merge_table_4.to_csv("merge_4_create_sech_clac_nm2.csv")

# %% [markdown]
#  * 160 ~ 200만개

# %%
# merge_table_5['sech_clac_nm2'] = merge_table_5['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)

# %%
# merge_table_5.to_csv("merge_5_create_sech_clac_nm2.csv")

# %% [markdown]
#  * 200 ~ 240만개

# %%
# merge_table_6['sech_clac_nm2'] = merge_table_6['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)

# %%
# merge_table_6.to_csv("merge_6_create_sech_clac_nm2.csv")

# %% [markdown]
#  * 240 ~ 280만개

# %%
# merge_table_7['sech_clac_nm2'] = merge_table_7['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)

# %%
# merge_table_7.to_csv("merge_7_create_sech_clac_nm2.csv")

# %% [markdown]
#  * 280 ~ 319만개

# %%
# merge_table_8['sech_clac_nm2'] = merge_table_8['sech_clac_nm1'].progress_map(clac_nm1_to_nm2)

# %%
# merge_table_8.to_csv("merge_8_create_sech_clac_nm2.csv")

# %%
------------------------------------------------------------------------------------------------------------------------------------

# %%
merge_table_1 = pd.read_csv("merge_1_create_sech_clac_nm2.csv")
merge_table_1.drop("Unnamed: 0", axis=1, inplace=True)
merge_table_2 = pd.read_csv("merge_2_create_sech_clac_nm2.csv")
merge_table_2.drop("Unnamed: 0", axis=1, inplace=True)
merge_table_3 = pd.read_csv("merge_3_create_sech_clac_nm2.csv")
merge_table_3.drop("Unnamed: 0", axis=1, inplace=True)
merge_table_4 = pd.read_csv("merge_4_create_sech_clac_nm2.csv")
merge_table_4.drop("Unnamed: 0", axis=1, inplace=True)
merge_table_5 = pd.read_csv("merge_5_create_sech_clac_nm2.csv")
merge_table_5.drop("Unnamed: 0", axis=1, inplace=True)
merge_table_6 = pd.read_csv("merge_6_create_sech_clac_nm2.csv")
merge_table_6.drop("Unnamed: 0", axis=1, inplace=True)
merge_table_7 = pd.read_csv("merge_7_create_sech_clac_nm2.csv")
merge_table_7.drop("Unnamed: 0", axis=1, inplace=True)
merge_table_8 = pd.read_csv("merge_8_create_sech_clac_nm2.csv")
merge_table_8.drop("Unnamed: 0", axis=1, inplace=True)
# Out:
# /home/aiffel0042/anaconda3/envs/aiffel/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (17,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
merge_table_add_nm2_all = pd.concat([merge_table_1, merge_table_2, merge_table_3, merge_table_4, merge_table_5, merge_table_6, merge_table_7, merge_table_8])

# %%
merge_table_add_nm2_all
# Out:
#         clnt_id  sess_id  hit_seq  action_type biz_unit   sess_dt hit_tm  \
# 0         72429        1        2            2      A03  20190919  22:09
# 1         72429        1        1            1      A03  20190919  22:09
# 2         72428        5        1            0      A01  20190918  06:37
# 3         72428        4        1            0      A01  20190914  23:42
# 4         72428        3        3            0      A01  20190914  21:50
# ...         ...      ...      ...          ...      ...       ...    ...
# 396357        1        2        2            0      A01  20190922  14:10
# 396358        1        2        1            0      A01  20190922  14:09
# 396359        1        1        3            0      A01  20190911  16:15
# 396360        1        1        2            0      A01  20190911  16:15
# 396361        1        1        1            0      A01  20190911  16:14
#
#         hit_pss_tm  trans_id    sech_kwd  ...  clnt_age  clac_nm1 clac_nm2  \
# 0           842130       NaN         NaN  ...   unknown       NaN      NaN
# 1           839064       NaN         NaN  ...   unknown       NaN      NaN
# 2            12568       NaN   라인에디션블라우스  ...   unknown       NaN      NaN
# 3           243555       NaN        펜디가방  ...   unknown       NaN      NaN
# 4           839771       NaN      페레가모가방  ...   unknown       NaN      NaN
# ...            ...       ...         ...  ...       ...       ...      ...
# 396357       56113       NaN      초등가을점퍼  ...   unknown       NaN      NaN
# 396358       41584       NaN      초등가을잠바  ...   unknown       NaN      NaN
# 396359       36140       NaN       과일바구니  ...   unknown       NaN      NaN
# 396360       22432       NaN  과일선물세트 백화점  ...   unknown       NaN      NaN
# 396361       11880       NaN      과일선물세트  ...   unknown       NaN      NaN
#
#        clac_nm3 pd_c_2  sech_kwd_over_3 sech_kwd_cat_0  sech_kwd_cat_1  \
# 0           NaN    NaN              NaN            NaN             NaN
# 1           NaN    NaN              NaN            NaN             NaN
# 2           NaN    NaN              NaN            NaN             NaN
# 3           NaN    NaN             펜디가방         명품/쥬얼리       수입명품/해외배송
# 4           NaN    NaN           페레가모가방         명품/쥬얼리       수입명품/해외배송
# ...         ...    ...              ...            ...             ...
# 396357      NaN    NaN              NaN            NaN             NaN
# 396358      NaN    NaN              NaN            NaN             NaN
# 396359      NaN    NaN            과일바구니       여행/렌탈/금융        렌탈/배달/케어
# 396360      NaN    NaN              NaN            NaN             NaN
# 396361      NaN    NaN           과일선물세트             식품            신선식품
#
#                    sech_clac_nm1          sech_clac_nm2
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3            Fashion Accessories                Jewelry
# 4            Fashion Accessories          Women's Shoes
# ...                          ...                    ...
# 396357                       NaN                    NaN
# 396358                       NaN                    NaN
# 396359  Living / Rental Services        Living Services
# 396360                       NaN                    NaN
# 396361             Chilled Foods  Chilled Instant Foods
#
# [3196362 rows x 32 columns]

# %%
merge_table_add_nm2_all.to_csv("merge_all_create_sech_clac_nm2.csv")

# %% [markdown]
#  * 데이터 불러오기

# %%
merge_table_add_nm2_all = pd.read_csv("merge_all_create_sech_clac_nm2.csv")
merge_table_add_nm2_all.drop("Unnamed: 0", axis=1, inplace=True)
# Out:
# /home/aiffel0042/anaconda3/envs/aiffel/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (17,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
merge_table_add_nm2_all
# Out:
#          clnt_id  sess_id  hit_seq  action_type biz_unit   sess_dt hit_tm  \
# 0          72429        1        2            2      A03  20190919  22:09
# 1          72429        1        1            1      A03  20190919  22:09
# 2          72428        5        1            0      A01  20190918  06:37
# 3          72428        4        1            0      A01  20190914  23:42
# 4          72428        3        3            0      A01  20190914  21:50
# ...          ...      ...      ...          ...      ...       ...    ...
# 3196357        1        2        2            0      A01  20190922  14:10
# 3196358        1        2        1            0      A01  20190922  14:09
# 3196359        1        1        3            0      A01  20190911  16:15
# 3196360        1        1        2            0      A01  20190911  16:15
# 3196361        1        1        1            0      A01  20190911  16:14
#
#          hit_pss_tm  trans_id    sech_kwd  ...  clnt_age  clac_nm1 clac_nm2  \
# 0            842130       NaN         NaN  ...   unknown       NaN      NaN
# 1            839064       NaN         NaN  ...   unknown       NaN      NaN
# 2             12568       NaN   라인에디션블라우스  ...   unknown       NaN      NaN
# 3            243555       NaN        펜디가방  ...   unknown       NaN      NaN
# 4            839771       NaN      페레가모가방  ...   unknown       NaN      NaN
# ...             ...       ...         ...  ...       ...       ...      ...
# 3196357       56113       NaN      초등가을점퍼  ...   unknown       NaN      NaN
# 3196358       41584       NaN      초등가을잠바  ...   unknown       NaN      NaN
# 3196359       36140       NaN       과일바구니  ...   unknown       NaN      NaN
# 3196360       22432       NaN  과일선물세트 백화점  ...   unknown       NaN      NaN
# 3196361       11880       NaN      과일선물세트  ...   unknown       NaN      NaN
#
#         clac_nm3 pd_c_2  sech_kwd_over_3 sech_kwd_cat_0  sech_kwd_cat_1  \
# 0            NaN    NaN              NaN            NaN             NaN
# 1            NaN    NaN              NaN            NaN             NaN
# 2            NaN    NaN              NaN            NaN             NaN
# 3            NaN    NaN             펜디가방         명품/쥬얼리       수입명품/해외배송
# 4            NaN    NaN           페레가모가방         명품/쥬얼리       수입명품/해외배송
# ...          ...    ...              ...            ...             ...
# 3196357      NaN    NaN              NaN            NaN             NaN
# 3196358      NaN    NaN              NaN            NaN             NaN
# 3196359      NaN    NaN            과일바구니       여행/렌탈/금융        렌탈/배달/케어
# 3196360      NaN    NaN              NaN            NaN             NaN
# 3196361      NaN    NaN           과일선물세트             식품            신선식품
#
#                     sech_clac_nm1          sech_clac_nm2
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3             Fashion Accessories                Jewelry
# 4             Fashion Accessories          Women's Shoes
# ...                           ...                    ...
# 3196357                       NaN                    NaN
# 3196358                       NaN                    NaN
# 3196359  Living / Rental Services        Living Services
# 3196360                       NaN                    NaN
# 3196361             Chilled Foods  Chilled Instant Foods
#
# [3196362 rows x 32 columns]

# %% [markdown]
# ## 구매이력의 중분류와 검색을 통해 유추한 중분류간 일치 정도 확인

# %% [markdown]
#  * 구매이력을 통한 중분류 갯수 : 5733개

# %%
merge_table_add_nm2_all[['clac_nm2', 'sech_clac_nm2']][(merge_table_add_nm2_all['clac_nm2'].isna() == False)]
# Out:
#                               clac_nm2        sech_clac_nm2
# 160                     Mobile Devices                  NaN
# 362           Processed Dairy Products                  NaN
# 438                          Hair Care                  NaN
# 902                             Others                  NaN
# 970          Canned Agricultural Foods                  NaN
# ...                                ...                  ...
# 3194666               Pet Cat Supplies                  NaN
# 3194931  Women's Upper Bodywear / Tops                  NaN
# 3195598    Preschoolers' Full Bodywear                  NaN
# 3196194                  Coffee Drinks  Musical Instruments
# 3196315                  Coffee Drinks             Biscuits
#
# [5733 rows x 2 columns]

# %% [markdown]
#  * 검색어로 유추한 중분류 갯수 : 1572140개

# %%
merge_table_add_nm2_all[['clac_nm2', 'sech_clac_nm2']][(merge_table_add_nm2_all['sech_clac_nm2'].isna() == False)]
# Out:
#         clac_nm2            sech_clac_nm2
# 3            NaN                  Jewelry
# 4            NaN            Women's Shoes
# 5            NaN            Women's Shoes
# 6            NaN            Women's Shoes
# 7            NaN  Men's Socks and Hosiery
# ...          ...                      ...
# 3196351      NaN               Chocolates
# 3196352      NaN                  Camping
# 3196354      NaN                 Climbing
# 3196359      NaN          Living Services
# 3196361      NaN    Chilled Instant Foods
#
# [1572140 rows x 2 columns]

# %% [markdown]
#  * 구매이력을 통한 중분류와 검색어로 추출한 중분류가 일치하지 않는 case : 1039개

# %%
merge_table_add_nm2_all[['clac_nm2', 'sech_clac_nm2']][(merge_table_add_nm2_all['clac_nm2'].isna() == False) & (merge_table_add_nm2_all['sech_clac_nm2'].isna() == False) & (merge_table_add_nm2_all['clac_nm2'] != merge_table_add_nm2_all['sech_clac_nm2'])]
# Out:
#                             clac_nm2         sech_clac_nm2
# 1712               Functional Drinks                Snacks
# 1793              Mobile Accessories             Skin Care
# 6118                          Makeup             Skin Care
# 9110                            Rice            Hot Snacks
# 9166                 Domestic Fruits  Packaged Side Dishes
# ...                              ...                   ...
# 3183294         Umbrellas / Parasols           Men's Shoes
# 3187821  Preschoolers' Full Bodywear    Baby Hygiene Goods
# 3193697                         Rice      Ham and Sausages
# 3196194                Coffee Drinks   Musical Instruments
# 3196315                Coffee Drinks              Biscuits
#
# [1039 rows x 2 columns]

# %%
merge_table_add_nm2_all[['clac_nm1', 'clac_nm2', 'sech_clac_nm1', 'sech_clac_nm2']][(merge_table_add_nm2_all['clac_nm2'].isna() == False) & (merge_table_add_nm2_all['sech_clac_nm2'].isna() == False) & (merge_table_add_nm2_all['clac_nm2'] != merge_table_add_nm2_all['sech_clac_nm2'])].head(50)
# Out:
#                                         clac_nm1  \
# 1712                                   Beverages
# 1793                   Cell Phones / Accessories
# 6118                     Cosmetics / Beauty Care
# 9110                                      Grains
# 9166                                      Fruits
# 9176                                      Grains
# 13186                              Sport Fashion
# 13386                    Cosmetics / Beauty Care
# 18259                        Fashion Accessories
# 27564                                  Beverages
# 28309                             Men's Clothing
# 30229                                  Beverages
# 30239                               Health Foods
# 30418                        Fashion Accessories
# 33099                                     Fruits
# 33652                        Fashion Accessories
# 34924                                  Beverages
# 36613                                     Grains
# 40996                                     Grains
# 41345                             Men's Clothing
# 43840                                  Beverages
# 45464                               Health Foods
# 48095                               Health Foods
# 49128                    Cosmetics / Beauty Care
# 56291                              Personal Care
# 58547                                  Beverages
# 61442                        Fashion Accessories
# 61466                               Health Foods
# 61618   Underwear / Socks and Hosiery / Homewear
# 64392                      Others (Non-Products)
# 69809                               Coffee / Tea
# 72507                               Health Foods
# 72934                               Health Foods
# 75312                                     Fruits
# 76333                                  Beverages
# 89626                                  Beverages
# 95723                                 Baby Foods
# 96185                              Sport Fashion
# 96443                           Women's Clothing
# 97430                               Coffee / Tea
# 98305                              Sport Fashion
# 98407                        Fashion Accessories
# 109782                       Fashion Accessories
# 111579                            Other Products
# 112565  Underwear / Socks and Hosiery / Homewear
# 112639                             Sport Fashion
# 116118                             Sport Fashion
# 118912                   Cosmetics / Beauty Care
# 119613                              Health Foods
# 120021                                 Beverages
#
#                                clac_nm2  \
# 1712                  Functional Drinks
# 1793                 Mobile Accessories
# 6118                             Makeup
# 9110                               Rice
# 9166                    Domestic Fruits
# 9176                               Rice
# 13186    Women's General Sport Clothing
# 13386                            Makeup
# 18259               Fashion Accessories
# 27564        Fruit and Vegetable Drinks
# 28309       Men's Upper Bodywear / Tops
# 30229                             Water
# 30239               Dietary Supplements
# 30418                     Women's Shoes
# 33099                   Domestic Fruits
# 33652                   Women's Wallets
# 34924                             Water
# 36613                              Rice
# 40996                              Rice
# 41345    Men's Lower Bodywear / Bottoms
# 43840                             Water
# 45464               Dietary Supplements
# 48095               Dietary Supplements
# 49128                            Makeup
# 56291                         Body Care
# 58547                          Soy Milk
# 61442                      Women's Bags
# 61466           Nutritional Supplements
# 61618                 Women's Underwear
# 64392                            Others
# 69809                   Premixed Coffee
# 72507               Dietary Supplements
# 72934               Dietary Supplements
# 75312                   Imported Fruits
# 76333                             Water
# 89626        Fruit and Vegetable Drinks
# 95723                        Baby Foods
# 96185               Women's Sport Shoes
# 96443                   Women's Outwear
# 97430                     Brewed Coffee
# 98305    Women's General Sport Clothing
# 98407                     Women's Shoes
# 109782              Fashion Accessories
# 111579  Special Offer Sales / B2B Sales
# 112565                Women's Underwear
# 112639   Women's General Sport Clothing
# 116118              Women's Sport Shoes
# 118912                        Skin Care
# 119613              Dietary Supplements
# 120021                      Soft Drinks
#
#                                    sech_clac_nm1  \
# 1712                                 Snack Foods
# 1793                     Cosmetics / Beauty Care
# 6118                     Cosmetics / Beauty Care
# 9110                                Cooked Foods
# 9166                               Chilled Foods
# 9176                               Chilled Foods
# 13186                              Sport Fashion
# 13386                    Cosmetics / Beauty Care
# 18259                        Fashion Accessories
# 27564                                Snack Foods
# 28309                        Fashion Accessories
# 30229                                Snack Foods
# 30239                               Cooked Foods
# 30418                        Fashion Accessories
# 33099                              Chilled Foods
# 33652                           Women's Clothing
# 34924                                Snack Foods
# 36613                           Gardening / Pets
# 40996                              Chilled Foods
# 41345                           Women's Clothing
# 43840                                Snack Foods
# 45464                                Snack Foods
# 48095                               Cooked Foods
# 49128                        Fashion Accessories
# 56291                                Kitchenware
# 58547                                Snack Foods
# 61442                                        Toy
# 61466                               Health Foods
# 61618   Underwear / Socks and Hosiery / Homewear
# 64392              Heating / Cooling Electronics
# 69809                                Snack Foods
# 72507                               Cooked Foods
# 72934                               Cooked Foods
# 75312                               Cooked Foods
# 76333                                Snack Foods
# 89626                                Snack Foods
# 95723             Birth Supplies / Baby Products
# 96185                              Sport Fashion
# 96443                           Women's Clothing
# 97430                  Gift Certificates / Cards
# 98305                              Sport Fashion
# 98407                        Fashion Accessories
# 109782                       Fashion Accessories
# 111579                          Gardening / Pets
# 112565                             Sport Fashion
# 112639                           Seasonal Sports
# 116118              Outdoor / Leisure Activities
# 118912                   Cosmetics / Beauty Care
# 119613                              Cooked Foods
# 120021                               Snack Foods
#
#                                   sech_clac_nm2
# 1712                                     Snacks
# 1793                                  Skin Care
# 6118                                  Skin Care
# 9110                                 Hot Snacks
# 9166                       Packaged Side Dishes
# 9176                       Packaged Side Dishes
# 13186                         Sport Accessories
# 13386                                  Perfumes
# 18259                              Women's Bags
# 27564                                    Snacks
# 28309                             Women's Shoes
# 30229                                      Pies
# 30239                            Chilled Snacks
# 30418                       Fashion Accessories
# 33099                         Chilled Beverages
# 33652             Women's Upper Bodywear / Tops
# 34924                                  Biscuits
# 36613                                Other Pets
# 40996                Fish Cakes and Crab Sticks
# 41345             Women's Upper Bodywear / Tops
# 43840                                  Biscuits
# 45464                                  Biscuits
# 48095                        Cooked Side Dishes
# 49128                               Hats / Caps
# 56291   Kitchen Organization / Disposable Goods
# 58547                               Chewing Gum
# 61442                                Boy's Toys
# 61466                                     Honey
# 61618                           Men's Underwear
# 64392                        Heating Appliances
# 69809                                    Snacks
# 72507                                Hot Snacks
# 72934                                    Bakery
# 75312                            Chilled Snacks
# 76333                                    Snacks
# 89626                                   Candies
# 95723                      Baby Growth Products
# 96185                         Sport Accessories
# 96443          Women's Lower Bodywear / Bottoms
# 97430                         Gift Certificates
# 98305              Men's General Sport Clothing
# 98407                              Women's Bags
# 109782                            Women's Shoes
# 111579                         Pet Dog Supplies
# 112565                      Women's Sport Shoes
# 112639                  Swimming / Water Sports
# 116118                                 Climbing
# 118912                                   Makeup
# 119613                               Hot Snacks
# 120021                                 Biscuits

# %%
merge_table_add_nm2_all[['clac_nm1', 'clac_nm2', 'sech_clac_nm1', 'sech_clac_nm2']][(merge_table_add_nm2_all['clac_nm2'].isna() == False) & (merge_table_add_nm2_all['sech_clac_nm2'].isna() == False) & (merge_table_add_nm2_all['clac_nm2'] == merge_table_add_nm2_all['sech_clac_nm2'])].head(50)
# Out:
#                                          clac_nm1  \
# 8179                      Cosmetics / Beauty Care
# 31687              Birth Supplies / Baby Products
# 41019                     Cosmetics / Beauty Care
# 88771               Heating / Cooling Electronics
# 97458                     Cosmetics / Beauty Care
# 141436              Heating / Cooling Electronics
# 265796                    Cosmetics / Beauty Care
# 289764                               Health Foods
# 333382   Underwear / Socks and Hosiery / Homewear
# 460967                    Cosmetics / Beauty Care
# 461398                    Cosmetics / Beauty Care
# 484343                               Health Foods
# 592984                    Cosmetics / Beauty Care
# 642237                    Cosmetics / Beauty Care
# 643660                    Cosmetics / Beauty Care
# 650781                    Cosmetics / Beauty Care
# 663835                               Health Foods
# 674912                              Chilled Foods
# 777246             Birth Supplies / Baby Products
# 959259             Birth Supplies / Baby Products
# 1003498                   Cosmetics / Beauty Care
# 1146669                      Bedding / Handicraft
# 1146678                      Bedding / Handicraft
# 1196386                          Gardening / Pets
# 1215779                   Cosmetics / Beauty Care
# 1226118                   Cosmetics / Beauty Care
# 1255030             Books / Records / Instruments
# 1274468                           Seasonal Sports
# 1296426                Detergents / Hygiene Goods
# 1313035                   Cosmetics / Beauty Care
# 1326574                 Gift Certificates / Cards
# 1381336             Heating / Cooling Electronics
# 1381342             Heating / Cooling Electronics
# 1392627                   Cosmetics / Beauty Care
# 1413193             Heating / Cooling Electronics
# 1525552                          Gardening / Pets
# 1551522                           Seasonal Sports
# 1553031                              Health Foods
# 1563846                       Fashion Accessories
# 1567850                              Health Foods
# 1662210                           Seasonal Sports
# 1662498                   Cosmetics / Beauty Care
# 1736530            Birth Supplies / Baby Products
# 1899987                          Women's Clothing
# 1899996                          Women's Clothing
# 1999372  Underwear / Socks and Hosiery / Homewear
# 2030192                          Women's Clothing
# 2034583                             Sport Fashion
# 2070014                             Chilled Foods
# 2093109                   Cosmetics / Beauty Care
#
#                                  clac_nm2  \
# 8179                            Skin Care
# 31687          Feeding / Weaning Products
# 41019                           Skin Care
# 88771                  Cooling Appliances
# 97458                           Skin Care
# 141436                 Cooling Appliances
# 265796                             Makeup
# 289764            Nutritional Supplements
# 333382                  Women's Underwear
# 460967                          Skin Care
# 461398                          Skin Care
# 484343            Nutritional Supplements
# 592984                             Makeup
# 642237                          Skin Care
# 643660                          Skin Care
# 650781                          Skin Care
# 663835            Nutritional Supplements
# 674912              Chilled Instant Foods
# 777246                 Baby Hygiene Goods
# 959259              Baby Safety Equipment
# 1003498                         Skin Care
# 1146669                   Adults' Bedding
# 1146678                   Adults' Bedding
# 1196386                  Pet Dog Supplies
# 1215779                            Makeup
# 1226118                            Makeup
# 1255030               Musical Instruments
# 1274468           Swimming / Water Sports
# 1296426                Tissues and Papers
# 1313035                            Makeup
# 1326574                 Mobile Gift Cards
# 1381336                Cooling Appliances
# 1381342                Cooling Appliances
# 1392627                         Skin Care
# 1413193                Cooling Appliances
# 1525552                  Pet Dog Supplies
# 1551522           Swimming / Water Sports
# 1553031           Nutritional Supplements
# 1563846                     Women's Shoes
# 1567850           Nutritional Supplements
# 1662210           Swimming / Water Sports
# 1662498                            Makeup
# 1736530                Baby Hygiene Goods
# 1899987     Women's Upper Bodywear / Tops
# 1899996     Women's Upper Bodywear / Tops
# 1999372                 Women's Underwear
# 2030192  Women's Lower Bodywear / Bottoms
# 2034583               Women's Sport Shoes
# 2070014             Chilled Instant Foods
# 2093109                          Sun Care
#
#                                     sech_clac_nm1  \
# 8179                      Cosmetics / Beauty Care
# 31687              Birth Supplies / Baby Products
# 41019                     Cosmetics / Beauty Care
# 88771               Heating / Cooling Electronics
# 97458                     Cosmetics / Beauty Care
# 141436              Heating / Cooling Electronics
# 265796                    Cosmetics / Beauty Care
# 289764                               Health Foods
# 333382   Underwear / Socks and Hosiery / Homewear
# 460967                    Cosmetics / Beauty Care
# 461398                    Cosmetics / Beauty Care
# 484343                               Health Foods
# 592984                    Cosmetics / Beauty Care
# 642237                    Cosmetics / Beauty Care
# 643660                    Cosmetics / Beauty Care
# 650781                    Cosmetics / Beauty Care
# 663835                               Health Foods
# 674912                              Chilled Foods
# 777246             Birth Supplies / Baby Products
# 959259             Birth Supplies / Baby Products
# 1003498                   Cosmetics / Beauty Care
# 1146669                      Bedding / Handicraft
# 1146678                      Bedding / Handicraft
# 1196386                          Gardening / Pets
# 1215779                   Cosmetics / Beauty Care
# 1226118                   Cosmetics / Beauty Care
# 1255030             Books / Records / Instruments
# 1274468                           Seasonal Sports
# 1296426                Detergents / Hygiene Goods
# 1313035                   Cosmetics / Beauty Care
# 1326574                 Gift Certificates / Cards
# 1381336             Heating / Cooling Electronics
# 1381342             Heating / Cooling Electronics
# 1392627                   Cosmetics / Beauty Care
# 1413193             Heating / Cooling Electronics
# 1525552                          Gardening / Pets
# 1551522                           Seasonal Sports
# 1553031                              Health Foods
# 1563846                       Fashion Accessories
# 1567850                              Health Foods
# 1662210                           Seasonal Sports
# 1662498                   Cosmetics / Beauty Care
# 1736530            Birth Supplies / Baby Products
# 1899987                          Women's Clothing
# 1899996                          Women's Clothing
# 1999372  Underwear / Socks and Hosiery / Homewear
# 2030192                          Women's Clothing
# 2034583                             Sport Fashion
# 2070014                             Chilled Foods
# 2093109                   Cosmetics / Beauty Care
#
#                             sech_clac_nm2
# 8179                            Skin Care
# 31687          Feeding / Weaning Products
# 41019                           Skin Care
# 88771                  Cooling Appliances
# 97458                           Skin Care
# 141436                 Cooling Appliances
# 265796                             Makeup
# 289764            Nutritional Supplements
# 333382                  Women's Underwear
# 460967                          Skin Care
# 461398                          Skin Care
# 484343            Nutritional Supplements
# 592984                             Makeup
# 642237                          Skin Care
# 643660                          Skin Care
# 650781                          Skin Care
# 663835            Nutritional Supplements
# 674912              Chilled Instant Foods
# 777246                 Baby Hygiene Goods
# 959259              Baby Safety Equipment
# 1003498                         Skin Care
# 1146669                   Adults' Bedding
# 1146678                   Adults' Bedding
# 1196386                  Pet Dog Supplies
# 1215779                            Makeup
# 1226118                            Makeup
# 1255030               Musical Instruments
# 1274468           Swimming / Water Sports
# 1296426                Tissues and Papers
# 1313035                            Makeup
# 1326574                 Mobile Gift Cards
# 1381336                Cooling Appliances
# 1381342                Cooling Appliances
# 1392627                         Skin Care
# 1413193                Cooling Appliances
# 1525552                  Pet Dog Supplies
# 1551522           Swimming / Water Sports
# 1553031           Nutritional Supplements
# 1563846                     Women's Shoes
# 1567850           Nutritional Supplements
# 1662210           Swimming / Water Sports
# 1662498                            Makeup
# 1736530                Baby Hygiene Goods
# 1899987     Women's Upper Bodywear / Tops
# 1899996     Women's Upper Bodywear / Tops
# 1999372                 Women's Underwear
# 2030192  Women's Lower Bodywear / Bottoms
# 2034583               Women's Sport Shoes
# 2070014             Chilled Instant Foods
# 2093109                          Sun Care
